# %% [markdown]
# ### Write a python program to print the frequency of each of the characters present in a given string

# %%
String = input("Enter the string :")
frequency = {}

for i in String:
    if i in frequency:
        frequency[i]+=1
    else:
        frequency[i]=1
print("The count of all character in",String,"is:\n ",str(frequency))
# Out:
# Enter the string :rohit kachhal
# The count of all character in rohit kachhal is:
#   {'r': 1, 'o': 1, 'h': 3, 'i': 1, 't': 1, ' ': 1, 'k': 1, 'a': 2, 'c': 1, 'l': 1}
