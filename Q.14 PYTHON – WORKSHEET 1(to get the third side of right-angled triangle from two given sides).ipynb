# %% [markdown]
# ### Q.14 Write a Python program to get the third side of right-angled triangle from two given sides.

# %%
from math import sqrt
print("Let's find the side of right-angled triangle if two sides is given --->")

Side = input("Enter the choice which side (Base,Height,Hypotenuse) you want to find :")

if Side =='Base':
    Height = float(input("Enter the Height of right-angled triangle :"))
    Hypotenuse = float(input("Enter the Hypotenuse of right-angled triangle :"))
    if Hypotenuse>Height:
        Base = math.sqrt(Hypotenuse*Hypotenuse-Height*Height)
        print("The Base of right-angled triangle is :",Base)
    else:
        print("Height should be less than Hypotenuse")
elif Side =='Height':
    Base = float(input("Enter the Base of right-angled triangle :"))
    Hypotenuse = float(input("Enter the Hypotenuse of right-angled triangle :"))
    if Hypotenuse>Base:
        Height = math.sqrt(Hypotenuse*Hypotenuse-Base*Base)
        print("The Height of right-angled triangle is :",Height)
    else:
        print("Base should be less than Hypotenuse")
elif Side =='Hypotenuse':
    Base = float(input("Enter the Base of right-angled triangle :"))
    Height = float(input("Enter the Height of right-angled triangle :"))
    Hypotenuse = math.sqrt((Base*Base)+(Height*Height))
    print("The Hypotenuse of right-angled triangle is :",Hypotenuse)
else:
    print("Enter an valid input")
# Out:
# Let's find the side of right-angled triangle if two sides is given --->
# Enter the choice which side (Base,Height,Hypotenuse) you want to find :Height
# Enter the Base of right-angled triangle :90
# Enter the Hypotenuse of right-angled triangle :45
# Base should be less than Hypotenuse

# %%
import numpy as np
print("Let's find the side of right-angled triangle if two sides is given --->")

Side = input("Enter the choice which side (Base,Height,Hypotenuse) you want to find :")

if Side =='Base':
    Height = float(input("Enter the Height of right-angled triangle :"))
    Hypotenuse = float(input("Enter the Hypotenuse of right-angled triangle :"))
    if Hypotenuse>Height:
        Base = np.sqrt(Hypotenuse*Hypotenuse-Height*Height)
        print("The Base of right-angled triangle is :",Base)
    else:
        print("Height should be less than Hypotenuse")    
elif Side =='Height':
    Base = float(input("Enter the Base of right-angled triangle :"))
    Hypotenuse = float(input("Enter the Hypotenuse of right-angled triangle :"))
    if Hypotenuse>Base:
        Height = np.sqrt(Hypotenuse*Hypotenuse-Base*Base)
        print("The Height of right-angled triangle is :",Height)
    else:
        print("Base should be less than Hypotenuse")    
elif Side =='Hypotenuse':
    Base = float(input("Enter the Base of right-angled triangle :"))
    Height = float(input("Enter the Height of right-angled triangle :"))
    Hypotenuse = np.sqrt((Base*Base)+(Height*Height))
    print("The Hypotenuse of right-angled triangle is :",Hypotenuse)
else:
    print("Enter an valid input")
# Out:
# Let's find the side of right-angled triangle if two sides is given --->
# Enter the choice which side (Base,Height,Hypotenuse) you want to find :Base
# Enter the Height of right-angled triangle :30
# Enter the Hypotenuse of right-angled triangle :50
# The Base of right-angled triangle is : 40.0
