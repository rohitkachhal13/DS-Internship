# %% [markdown]
# ### Q.2

# %%
print(2//3)
# Out:
# 0

# %% [markdown]
# ### Q.3

# %%
print(6<<2 )
# Out:
# 24

# %% [markdown]
# ### Q.4

# %%
print(6&2)
# Out:
# 2

# %% [markdown]
# ### Q.5

# %%
print(6|2)
# Out:
# 6

# %% [markdown]
# ### Q.9

# %%
_abc = 1
_abc
# Out:
# 1

# %%
1abc = 1
1abc
# Out:
#   File "<ipython-input-8-d2f91f15286d>", line 1
#     1abc = 1
#      ^
# SyntaxError: invalid syntax

# %%
abc2 = 1
abc2
# Out:
# 1
